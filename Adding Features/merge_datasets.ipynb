# %%
import pandas as pd
df1 = pd.read_csv("main_2000_onwards.csv")
df2 = pd.read_csv("football_2000_onwards.csv")
df1.shape
# Out:
# (6840, 23)

# %%
df1.head()
# Out:
#    premid  11id  season        date      home score           away  \
# 0    3287   816       9  2000-08-19  charlton   4-0       man city
# 1    3288   817       9  2000-08-19   chelsea   4-2       west ham
# 2    3289   818       9  2000-08-19  coventry   1-3  middlesbrough
# 3    3290   819       9  2000-08-19     derby   2-2    southampton
# 4    3291   820       9  2000-08-19     leeds   2-0        everton
#
#                 ref          stadium                         h_scorers  \
# 0        rob harris       the valley  ['1481', '1635', '2269', '2473']
# 1     graham barber  stamford bridge   ['107', '2452', '2452', '3761']
# 2      barry knight   highfield road                           ['136']
# 3       andy d'urso       pride park                    ['158', '162']
# 4  dermot gallagher      elland road                    ['212', '212']
#
#     ...    hPos hGSPG hGCPG  hCSPG  hPtsPG  aPos  aGSPG  aGCPG  aCSPG  aPtsPG
# ...

# %%
df2.head()
# Out:
#         date2     home2 score2          away2   hs2   as2  hst2  ast2
# 0  2000-08-19  charlton    4-0       man city  17.0   8.0  14.0   4.0
# 1  2000-08-19   chelsea    4-2       west ham  17.0  12.0  10.0   5.0
# 2  2000-08-19  coventry    1-3  middlesbrough   6.0  16.0   3.0   9.0
# 3  2000-08-19     derby    2-2    southampton   6.0  13.0   4.0   6.0
# 4  2000-08-19     leeds    2-0        everton  17.0  12.0   8.0   6.0

# %%
df = pd.concat([df1,df2],axis=1)

# %%
df.head()
# Out:
#    premid  11id  season        date      home score           away  \
# 0    3287   816       9  2000-08-19  charlton   4-0       man city
# 1    3288   817       9  2000-08-19   chelsea   4-2       west ham
# 2    3289   818       9  2000-08-19  coventry   1-3  middlesbrough
# 3    3290   819       9  2000-08-19     derby   2-2    southampton
# 4    3291   820       9  2000-08-19     leeds   2-0        everton
#
#                 ref          stadium                         h_scorers  ...   \
# 0        rob harris       the valley  ['1481', '1635', '2269', '2473']  ...
# 1     graham barber  stamford bridge   ['107', '2452', '2452', '3761']  ...
# 2      barry knight   highfield road                           ['136']  ...
# 3       andy d'urso       pride park                    ['158', '162']  ...
# 4  dermot gallagher      elland road                    ['212', '212']  ...
#
#   aCSPG aPtsPG       date2     home2  score2          away2   hs2   as2  hst2  \
# ...

# %%
def cols_agree(row,col1,col2):
    return (str(row[col1]) == str(row[col2]))

# %%
df['home_agree'] = df.apply(cols_agree,args=('home','home2'),axis=1)
df['away_agree'] = df.apply(cols_agree,args=('away','away2'),axis=1)
df['score_agree'] = df.apply(cols_agree,args=('score','score2'),axis=1)
df['date_agree'] = df.apply(cols_agree,args=('date','date2'),axis=1)

# %%
def cols_agree(row,col1,col2):
    return (str(row[col1]) == str(row[col2]))
df['home_agree'] = df.apply(cols_agree,args=('home','home2'),axis=1)
df['home_agree'].value_counts()
# Out:
# True    6840
# Name: home_agree, dtype: int64

# %%
df['away_agree'].value_counts()
# Out:
# True    6840
# Name: away_agree, dtype: int64

# %%
df['score_agree'].value_counts()
# Out:
# True    6840
# Name: score_agree, dtype: int64

# %%
df['date_agree'].value_counts()
# Out:
# True    6840
# Name: date_agree, dtype: int64

# %%
df.head(100)
# Out:
#     premid  11id  season        date           home score           away  \
# 0     3287   816       9  2000-08-19       charlton   4-0       man city
# 1     3288   817       9  2000-08-19        chelsea   4-2       west ham
# 2     3289   818       9  2000-08-19       coventry   1-3  middlesbrough
# 3     3290   819       9  2000-08-19          derby   2-2    southampton
# 4     3291   820       9  2000-08-19          leeds   2-0        everton
# 5     3292   821       9  2000-08-19      leicester   0-0    aston villa
# 6     3293   822       9  2000-08-19      liverpool   1-0       bradford
# 7     3295   824       9  2000-08-19          spurs   3-1        ipswich
# 8     3294   823       9  2000-08-19     sunderland   1-0        arsenal
# 9     3296   827       9  2000-08-20        man utd   2-0      newcastle
# 10    3297   859       9  2000-08-21        arsenal   2-0      liverpool
# 11    3298   900       9  2000-08-22       bradford   2-0        chelsea
# ...

# %%
df.tail(100)
# Out:
#       premid    11id  season        date            home score  \
# 6740   22623  356821      26  2018-03-03         burnley   2-1
# 6741   22625  356822      26  2018-03-03       leicester   1-1
# 6742   22626  356827      26  2018-03-03       liverpool   2-0
# 6743   22628  356823      26  2018-03-03     southampton   0-0
# 6744   22630  356825      26  2018-03-03           spurs   2-0
# 6745   22629  356824      26  2018-03-03         swansea   4-1
# 6746   22631  356826      26  2018-03-03         watford   1-0
# 6747   22622  356862      26  2018-03-04        brighton   2-1
# 6748   22627  356863      26  2018-03-04        man city   1-0
# 6749   22624  356865      26  2018-03-05  crystal palace   2-3
# 6750   22634  356888      26  2018-03-10         chelsea   2-1
# 6751   22635  356883      26  2018-03-10         everton   2-0
# 6752   22636  356884      26  2018-03-10    huddersfield   0-0
# 6753   22637  356882      26  2018-03-10         man utd   2-1
# ...

# %%
df_disagree = df[[not(x) for x in df.home_agree]]

# %%
df_disagree.shape
# Out:
# (0, 35)

# %%
df_disagree['home2']
# Out:
# Series([], Name: home2, dtype: object)

# %%
df.columns
# Out:
# Index(['premid', '11id', 'season', 'date', 'home', 'score', 'away', 'ref',
#        'stadium', 'h_scorers', 'a_scorers', 'h_players', 'a_players', 'hPos',
#        'hGSPG', 'hGCPG', 'hCSPG', 'hPtsPG', 'aPos', 'aGSPG', 'aGCPG', 'aCSPG',
#        'aPtsPG', 'date2', 'home2', 'score2', 'away2', 'hs2', 'as2', 'hst2',
#        'ast2', 'home_agree', 'away_agree', 'score_agree', 'date_agree'],
#       dtype='object')

# %%
df.drop(['date2','home2','score2','away2','home_agree','away_agree','score_agree','date_agree'],inplace=True,axis=1)

# %%
df.columns
# Out:
# Index(['premid', '11id', 'season', 'date', 'home', 'score', 'away', 'ref',
#        'stadium', 'h_scorers', 'a_scorers', 'h_players', 'a_players', 'hPos',
#        'hGSPG', 'hGCPG', 'hCSPG', 'hPtsPG', 'aPos', 'aGSPG', 'aGCPG', 'aCSPG',
#        'aPtsPG', 'hs2', 'as2', 'hst2', 'ast2'],
#       dtype='object')

# %%
df.to_csv("main_with_shots.csv",index=False)
