# %%
import pandas as pd
import numpy as np
df = pd.read_csv("1-data_all_prem_data.csv")

# %%
refs = df['Referee'].tolist()
for ref in refs:
    if ref not in set(['alan gunn', 'alan wiley', 'alan wilkie', 'alf buksh', 'andre marriner', "andy d' urso", 'andy madley', 'anthony taylor', 'barry knight', 'bob hamer', 'bob nixon', 'bobby madley', 'brian hill', 'chris foy', 'chris kavanagh', 'clive wilkes', 'craig pawson', 'david allison', 'david coote', 'david crick', 'david elleray', 'david frampton', 'david pugh', 'dermot gallagher', 'eddie wolstenholme', 'frazer stretton', 'gary willard', 'gerald ashby', 'graham barber', 'graham poll', 'graham scott', 'howard king', 'howard webb', 'i mitchell', 'jeff winter', 'jim borrett', 'joe worrall', 'john e martin', 'john key', 'john lloyd', 'jonathan moss', 'keith burge', 'keith cooper', 'keith hackett', 'keith stroud', 'kelvin morton', 'ken redfern', 'keren barratt', 'kevin friend', 'lee mason', 'lee probert', 'mark clattenburg', 'mark halsey', 'martin atkinson', 'martin bodenham', 'matt messias', 'michael jones', 'michael oliver', 'mike dean', 'mike peck', 'mike reed', 'mike riley', 'neale barry', 'neil swarbrick', 'paul alcock', 'paul danson', 'paul durkin', 'paul taylor', 'paul tierney', 'peter foakes', 'peter jones', 'peter walton', 'phil crossley', 'phil dowd', 'philip don', 'philip wright', 'ray bigger', 'ray lewis', 'richard beeby', 'rob harris', 'rob styles', 'robbie hart', 'rodger gifford', 'roger dilkes', 'roger east', 'roger milford', 'ron groves', 'simon hooper', 'steve bennett', 'steve dunn', 'steve lodge', 'steve tanner', 'stuart attwell', 't lloyd', 'terry holbrook', 'tony ward', 'uriah rennie', 'vic callow']):
        print(ref)
# Out:
# robert hart
# stephen lodge
# robert hart
# gary lewis
# john martin
# robert hart
# george pearson
# robert hart
# stephen lodge
# peter willis
# john martin
# john martin
# stephen lodge
# alain hamer
# gary lewis
# robert hart
# gary lewis
# stephen lodge
# stephen lodge
# robert hart
# robert hart
# stephen lodge
# stephen lodge
# stephen lodge
# robert hart
# robert hart
# stephen lodge
# robert hart
# stephen lodge
# john martin
# robert hart
# john martin
# paul ward
# stephen lodge
# john martin
# kevin wright
# mick fletcher
# paul ward
# john martin
# paul ward
# robert hart
# stephen lodge
# paul ward
# john martin
# stephen lodge
# paul ward
# gary lewis
# stephen lodge
# robert hart
# john martin
# gary lewis
# robert hart
# john martin
# john martin
# paul ward
# paul ward
# john martin
# stephen lodge
# robert hart
# paul ward
# gary lewis
# stephen lodge
# robert hart
# stephen lodge
# robert hart
# stephen lodge
# robert hart
# robert hart
# stephen lodge
# ...

# %%
print(len(df))
# Out:
# 10652

# %%
all_teams = set(df['Home Team'].tolist())
all_teams_dict = {}
for team in all_teams:
    all_teams_dict[team] = 0
for i in range(len(df)):
    row = df.iloc[i]
    hteam = row['Home Team']
    ateam = row['Away Team']
    all_teams_dict[hteam] += 1
    all_teams_dict[ateam] += 1
print(all_teams_dict)
# Out:
# {nan: 4, 'birmingham': 269, 'bolton': 527, 'brighton': 42, 'middlesbrough': 610, 'charlton': 309, 'portsmouth': 267, 'man utd': 1038, 'everton': 1034, 'oldham': 88, 'sheffield wed': 318, 'swindon': 44, 'watford': 193, 'hull': 198, 'leicester': 489, 'newcastle': 917, 'nottingham forest': 201, 'west ham': 879, 'chelsea': 1040, 'spurs': 1060, 'burnley': 155, 'wimbledon': 317, 'west brom': 490, 'leeds': 470, 'coventry': 358, 'aston villa': 953, 'stoke': 415, 'huddersfield': 43, 'sheffield utd': 128, 'norwich': 349, 'southampton': 766, 'ipswich': 202, 'crystal palace': 362, 'man city': 945, 'wolves': 192, 'wigan': 309, 'barnsley': 42, 'derby': 271, 'liverpool': 1101, 'bradford': 77, 'fulham': 532, 'blackpool': 39, 'arsenal': 1037, 'reading': 142, 'swansea': 271, 'cardiff': 42, 'blackburn': 727, 'bournemouth': 117, 'sunderland': 644, 'qpr': 281}
